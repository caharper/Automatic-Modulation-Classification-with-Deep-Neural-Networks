# %%
import sys

sys.path.append("./..")

# %%
import tensorflow as tf
import os
from amc_neural_networks.data_loading import (
    load_tfrecords,
    get_tf_batch,
    get_n_tfrecord_files,
)
from amc_neural_networks.model import create_model

# %%
dataset_root_path = 'path/to/tfrecord/dataset'
n_train_files = get_n_tfrecord_files(dataset_root_path, "train")
n_test_files = get_n_tfrecord_files(dataset_root_path, "test")

# %%
BATCH_SIZE = 32
train_ds = (
    load_tfrecords(dataset_root_path, split="train")
    .shuffle(n_train_files, reshuffle_each_iteration=True)
    .interleave(
        tf.data.TFRecordDataset,
        cycle_length=tf.data.AUTOTUNE,
        num_parallel_calls=tf.data.AUTOTUNE,
    )
    .batch(BATCH_SIZE)
    .map(get_tf_batch)
    .prefetch(tf.data.AUTOTUNE)
)

test_ds = (
    load_tfrecords(dataset_root_path, split="test")
    .interleave(
        tf.data.TFRecordDataset,
        cycle_length=tf.data.AUTOTUNE,
        num_parallel_calls=tf.data.AUTOTUNE,
    )
    .batch(BATCH_SIZE)
    .map(get_tf_batch)
    .prefetch(tf.data.AUTOTUNE)
)

eval_ds = (
    load_tfrecords(dataset_root_path, split="test")
    .interleave(
        tf.data.TFRecordDataset,
        cycle_length=tf.data.AUTOTUNE,
        num_parallel_calls=tf.data.AUTOTUNE,
    )
    .batch(BATCH_SIZE)
    .map(lambda x: get_tf_batch(x, with_snr=True))
    .prefetch(tf.data.AUTOTUNE)
)

# %%
model = create_model(
    use_se=True, use_act=True, residual=False, dilate=True, self_attention=False,
)
adam = tf.keras.optimizers.Adam(lr=1e-4, clipnorm=1)
model.compile(
    adam,
    loss=["sparse_categorical_crossentropy"],
    metrics=[
        "acc",
        tf.keras.metrics.SparseTopKCategoricalAccuracy(
            k=2, name="top_2_acc", dtype=None
        ),
    ],
)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 1024, 2)]    0
# __________________________________________________________________________________________________
# conv_1 (Conv1D)                 (None, 1024, 32)     480         input[0][0]
# __________________________________________________________________________________________________
# se_block_1_stat (GlobalAverageP (None, 32)           0           conv_1[0][0]
# __________________________________________________________________________________________________
# se_block_1_reshape (Reshape)    (None, 1, 32)        0           se_block_1_stat[0][0]
# __________________________________________________________________________________________________
# se_block_1_dense_1 (Dense)      (None, 1, 16)        512         se_block_1_reshape[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 1, 16)        0           se_block_1_dense_1[0][0]
# __________________________________________________________________________________________________
# se_block_1_dense_2 (Dense)      (None, 1, 32)        512         re_lu[0][0]
# __________________________________________________________________________________________________
# se_block_1_mult (Multiply)      (None, 1024, 32)     0           conv_1[0][0]
#                                                                  se_block_1_dense_2[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv1D)                 (None, 1024, 48)     7728        se_block_1_mult[0][0]
# __________________________________________________________________________________________________
# se_block_2_stat (GlobalAverageP (None, 48)           0           conv_2[0][0]
# __________________________________________________________________________________________________
# se_block_2_reshape (Reshape)    (None, 1, 48)        0           se_block_2_stat[0][0]
# __________________________________________________________________________________________________
# se_block_2_dense_1 (Dense)      (None, 1, 24)        1152        se_block_2_reshape[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 1, 24)        0           se_block_2_dense_1[0][0]
# __________________________________________________________________________________________________
# se_block_2_dense_2 (Dense)      (None, 1, 48)        1152        re_lu_1[0][0]
# __________________________________________________________________________________________________
# se_block_2_mult (Multiply)      (None, 1024, 48)     0           conv_2[0][0]
#                                                                  se_block_2_dense_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv1D)                 (None, 1024, 64)     21568       se_block_2_mult[0][0]
# __________________________________________________________________________________________________
# se_block_3_stat (GlobalAverageP (None, 64)           0           conv_3[0][0]
# __________________________________________________________________________________________________
# se_block_3_reshape (Reshape)    (None, 1, 64)        0           se_block_3_stat[0][0]
# __________________________________________________________________________________________________
# se_block_3_dense_1 (Dense)      (None, 1, 32)        2048        se_block_3_reshape[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 1, 32)        0           se_block_3_dense_1[0][0]
# __________________________________________________________________________________________________
# se_block_3_dense_2 (Dense)      (None, 1, 64)        2048        re_lu_2[0][0]
# __________________________________________________________________________________________________
# se_block_3_mult (Multiply)      (None, 1024, 64)     0           conv_3[0][0]
#                                                                  se_block_3_dense_2[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv1D)                 (None, 1024, 72)     23112       se_block_3_mult[0][0]
# __________________________________________________________________________________________________
# se_block_4_stat (GlobalAverageP (None, 72)           0           conv_4[0][0]
# __________________________________________________________________________________________________
# se_block_4_reshape (Reshape)    (None, 1, 72)        0           se_block_4_stat[0][0]
# __________________________________________________________________________________________________
# se_block_4_dense_1 (Dense)      (None, 1, 36)        2592        se_block_4_reshape[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 1, 36)        0           se_block_4_dense_1[0][0]
# __________________________________________________________________________________________________
# se_block_4_dense_2 (Dense)      (None, 1, 72)        2592        re_lu_3[0][0]
# __________________________________________________________________________________________________
# se_block_4_mult (Multiply)      (None, 1024, 72)     0           conv_4[0][0]
#                                                                  se_block_4_dense_2[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv1D)                 (None, 1024, 84)     18228       se_block_4_mult[0][0]
# __________________________________________________________________________________________________
# se_block_5_stat (GlobalAverageP (None, 84)           0           conv_5[0][0]
# __________________________________________________________________________________________________
# se_block_5_reshape (Reshape)    (None, 1, 84)        0           se_block_5_stat[0][0]
# __________________________________________________________________________________________________
# se_block_5_dense_1 (Dense)      (None, 1, 42)        3528        se_block_5_reshape[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 1, 42)        0           se_block_5_dense_1[0][0]
# __________________________________________________________________________________________________
# se_block_5_dense_2 (Dense)      (None, 1, 84)        3528        re_lu_4[0][0]
# __________________________________________________________________________________________________
# se_block_5_mult (Multiply)      (None, 1024, 84)     0           conv_5[0][0]
#                                                                  se_block_5_dense_2[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv1D)                 (None, 1024, 96)     24288       se_block_5_mult[0][0]
# __________________________________________________________________________________________________
# se_block_6_stat (GlobalAverageP (None, 96)           0           conv_6[0][0]
# __________________________________________________________________________________________________
# se_block_6_reshape (Reshape)    (None, 1, 96)        0           se_block_6_stat[0][0]
# __________________________________________________________________________________________________
# se_block_6_dense_1 (Dense)      (None, 1, 48)        4608        se_block_6_reshape[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 1, 48)        0           se_block_6_dense_1[0][0]
# __________________________________________________________________________________________________
# se_block_6_dense_2 (Dense)      (None, 1, 96)        4608        re_lu_5[0][0]
# __________________________________________________________________________________________________
# se_block_6_mult (Multiply)      (None, 1024, 96)     0           conv_6[0][0]
#                                                                  se_block_6_dense_2[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv1D)                 (None, 1024, 108)    31212       se_block_6_mult[0][0]
# __________________________________________________________________________________________________
# gap (GlobalAveragePooling1D)    (None, 108)          0           conv_7[0][0]
# __________________________________________________________________________________________________
# gvp (GlobalVariancePooling1D)   (None, 108)          0           conv_7[0][0]
# __________________________________________________________________________________________________
# stat_pool (Concatenate)         (None, 216)          0           gap[0][0]
#                                                                  gvp[0][0]
# __________________________________________________________________________________________________
# dense_variant_1 (Dense)         (None, 128)          27776       stat_pool[0][0]
# __________________________________________________________________________________________________
# act_variant_1 (Activation)      (None, 128)          0           dense_variant_1[0][0]
# __________________________________________________________________________________________________
# dense_variant_2 (Dense)         (None, 128)          16512       act_variant_1[0][0]
# __________________________________________________________________________________________________
# act_variant_2 (Activation)      (None, 128)          0           dense_variant_2[0][0]
# __________________________________________________________________________________________________
# variant (Dense)                 (None, 24)           3096        act_variant_2[0][0]
# ==================================================================================================
# Total params: 202,880
# Trainable params: 202,880
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
N_EPOCHS = 1
callbacks = [
    tf.keras.callbacks.TerminateOnNaN(),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="loss", factor=0.1, patience=12, min_lr=1e-7, mode="min"
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="loss", mode="min", patience=20, restore_best_weights=True
    ),
]

history = model.fit(
    train_ds, 
    steps_per_epoch=1, # remove to train on whole dataset
    validation_data=test_ds,
    validation_steps=1, # remove to train on whole dataset
    callbacks=callbacks, 
    epochs=N_EPOCHS, 
    verbose=2
)
# Out:
# 1/1 - 3s - loss: 3.1778 - acc: 0.0625 - top_2_acc: 0.1250 - val_loss: 3.1775 - val_acc: 0.0625 - val_top_2_acc: 0.0938

# %% [markdown]
# If you would like to include logging, checkpoints, and TensorBoard, the following code can also be used for callbacks before `model.fit`.
#
# ```python
#
# callbacks.extend(
#     [
#         tf.keras.callbacks.CSVLogger(os.path.join(save_dir, "training.log")),
#         tf.keras.callbacks.ModelCheckpoint(
#             os.path.join(save_dir, "model.hdf5"),
#             monitor="val_loss",
#             save_best_only=True,
#             mode="min",
#         ),
#         tf.keras.callbacks.TensorBoard(log_dir=os.path.join(save_dir, "logs")),
#     ]
# )
#
# ```
